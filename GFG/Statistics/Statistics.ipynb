# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./Students_marks.csv')

# %%
data.head()
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# 3          25.33  Very Good
# 4          18.00       Okay

# %%
data.describe()
# Out:
#        Roll No.  Data Structure  Mathematics  Operating System  Average marks
# count  10.00000       10.000000     10.00000         10.000000      10.000000
# mean    5.50000       40.700000     23.10000         20.600000      28.131000
# std     3.02765       52.493492      3.60401          6.619836      19.337093
# min     1.00000       21.000000     18.00000          9.000000      18.000000
# 25%     3.25000       23.000000     21.25000         15.500000      20.330000
# 50%     5.50000       24.000000     22.50000         21.500000      22.665000
# 75%     7.75000       25.750000     24.75000         26.500000      24.997500
# max    10.00000      190.000000     30.00000         28.000000      82.660000

# %%
plt.plot(data["Name"], data["Data Structure"])
plt.title("Marks of students in Data Structure")
plt.xlabel("Students Name")
plt.ylabel("Students Marks")
plt.show()

# %%
data.set_index(['Name'], inplace = True)
data
# Out:
#          Roll No. Gender  Data Structure  Mathematics  Operating System  \
# Name
# Avneet          1      F              25           19                17
# Jay             2      M              23           21                14
# Sadaf           3      F              28           23                21
# Prakash         4      M              21           27                28
# Sarita          5      F              23           22                 9
# Vasudha         6      F             190           30                28
# Ankur           7      M              24           24                22
# Laksh           8      M              26           25                27
# Aman            9      M              23           18                25
# Rajat          10      M              24           22                15
#
#          Average marks    Ranking
# Name
# Avneet           20.33       Good
# Jay              19.33       Okay
# Sadaf            24.00       Good
# Prakash          25.33  Very Good
# Sarita           18.00       Okay
# Vasudha          82.66  Very Good
# Ankur            23.33       Good
# Laksh            26.00  Very Good
# Aman             22.00       Good
# Rajat            20.33       Good

# %%
data.loc['Vasudha']
# Out:
# Roll No.                    6
# Gender                      F
# Data Structure            190
# Mathematics                30
# Operating System           28
# Average marks           82.66
# Ranking             Very Good
# Name: Vasudha, dtype: object

# %%
data = data.drop(index = 'Vasudha')

# %%
plt.plot(data.index, data["Data Structure"])
plt.title("Marks of students in Data Structure")
plt.xlabel("Students Name")
plt.ylabel("Students Marks")
plt.show()
